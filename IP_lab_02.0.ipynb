# %% [markdown]
# <a href="https://colab.research.google.com/github/Fairooz14/Image_Processing/blob/main/IP_lab_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab 02 : Color Convertion**

# %% [markdown]
# Study More : [OpenCV](https://docs.opencv.org/3.4/d8/d01/group__imgproc__color__conversions.html)

# %%
import cv2 # Open CV Load
from PIL import Image # Pillow load
from matplotlib import pyplot as plt # matpotlib load from graph
from google.colab.patches import cv2_imshow

# %%
image_path = '/content/image-1.jpg'

# %%
# loading using CV
image_bgr = cv2.imread(image_path)

# %% [markdown]
# ## **Loading BGR Image**

# %%
plt.imshow(image_bgr)

# %% [markdown]
# ## **Converting BGR to RGB**

# %%
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)

# %% [markdown]
# ## **Convertiong BGR to Gray**

# %%
image_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray)

# %% [markdown]
# > viridis er karone yellow color dekhacchilo grayscale e tai cmap use korte hoi

# %%
image_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
gray = plt.imshow(image_gray, cmap='gray')

# %% [markdown]
# ## **Converting BGR to RGBA**

# %%
image_rgba = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGBA)
plt.imshow(image_rgb, alpha=0.5)
