# %% [markdown]
# <a href="https://colab.research.google.com/github/Fairooz14/Image_Processing/blob/main/IP_lab_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab 01 : Basics of IP (load, display, save)**

# %% [markdown]
# There are 2 types of paths:
#
#
# *   Absolute : uploaded in drive
# *   Relative : uploaded in session locally.

# %%
import cv2 # Open CV Load
from PIL import Image # Pillow load
from matplotlib import pyplot as plt # matpotlib load from graph

from google.colab.patches import cv2_imshow

# %% [markdown]
# ## **Image load**
#
# loading image from session lopcally

# %%
image_path = '/content/sunflower.jpg'

# %% [markdown]
# loading from drive

# %%
image_path_drive = '/content/drive/MyDrive/Image_Processing_lab/Lab_01/sunflower.jpg'

# %% [markdown]
# Loading using CV, Pillow, matplotlib

# %%
# loading using CV
image_bgr = cv2.imread(image_path)

# %%
# loading using pillow
image_rgb = Image.open(image_path)

# %%
# loading using matpotlib
image_rgb = plt.imread(image_path)

# %% [markdown]
# ## **Image Info**

# %% [markdown]
# > Images loads in `numpy array`

# %%
print(image_rgb)
# Out:
# [[[255 248 225]
#   [255 247 224]
#   [255 247 224]
#   ...
#   [220 157   0]
#   [219 156   1]
#   [219 156   1]]
#
#  [[255 248 225]
#   [255 248 225]
#   [255 247 224]
#   ...
#   [220 157   0]
#   [219 156   1]
#   [218 155   0]]
#
#  [[255 248 225]
#   [255 248 225]
#   [255 248 225]
#   ...
#   [219 156   1]
#   [218 155   0]
#   [218 155   0]]
#
#  ...
#
#  [[ 65  39   2]
#   [ 65  39   2]
#   [ 65  39   2]
#   ...
#   [255 200   1]
#   [255 200   1]
#   [255 200   1]]
#
#  [[ 64  38   1]
#   [ 64  38   1]
#   [ 64  38   1]
#   ...
#   [254 201   1]
#   [254 201   1]
#   [254 201   1]]
#
#  [[ 64  38   1]
#   [ 64  38   1]
#   [ 64  38   1]
#   ...
#   [254 201   1]
#   [254 201   1]
#   [254 201   1]]]

# %% [markdown]
# > the shape shows : Height, Width and Channel

# %%
image_rgb.shape
# Out:
# (960, 640, 3)

# %%
image_bgr.shape
# Out:
# (960, 640, 3)

# %% [markdown]
# ## **Image Display**

# %% [markdown]
# display using pillow and matplotlib
#
# > Open CV by default image save kore BGR e , then it get swiped with RGB Image
#
#
# > plt diye korte hole RGB te convert korte hobe

# %%
plt.imshow(image_bgr)

# %% [markdown]
# displaying using open CV

# %%
cv2_imshow(image_bgr)
# Out:
# <PIL.Image.Image image mode=RGB size=640x960>

# %% [markdown]
# ## **Image Save**

# %% [markdown]
# save in Open CV

# %%
cv2.imwrite('sunflower_bgr.jpg', image_bgr)
# Out:
# True

# %% [markdown]
# save in Pillow

# %%
plt.imsave('sunflower_rgb.jpg', image_rgb)
